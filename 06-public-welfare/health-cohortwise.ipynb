# %%
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind

# %%
df = pd.read_parquet('data/health-indicators.parquet')
cohorts = pd.read_parquet('data/hh-cohorts.parquet')
hh = pd.read_parquet('data/hh_details.parquet')
cons = pd.read_parquet('data/baskets-consumption-value.parquet')

# %%
df = df[df['is_hospitalization'] != 4]
df['mult'] = hh['multiplier']
df['cohort_id'] = cohorts['cohort_id']

# %%
df['hosp_spend'] = cons.loc[df.index, "HOSP"]

# %%
df['nohosp'] = cons.loc[df.index, "NOHOSP"]

# %%
df.head()
# Out:
#           is_hhmem_pmjay  is_hospitalization  is_benefit_healthscheme   mult  \
# hhid
# 22300304               2                   2                      2.0  28599
# 22300308               2                   2                      2.0  28599
# 22300313               2                   2                      2.0  28599
# 22301201               2                   3                      2.0  20463
# 22301310               2                   1                      2.0  16099
#
#           cohort_id   hosp_spend
# hhid
# 22300304      21773  3250.000000
# 22300308      21722  2650.000000
# 22300313      21728  3916.666667
# 22301201      21732   500.000000
# 22301310      21782     4.166667

# %%
counts = df.groupby('cohort_id')['is_benefit_healthscheme'].value_counts().unstack().dropna()
counts = counts[counts.min(axis=1) > 1]

# %%
def compare_within_cohort(xdf):
    treatment = xdf[xdf['is_benefit_healthscheme'] == 1][['mult', 'hosp_spend']]
    control = xdf[xdf['is_benefit_healthscheme'] != 1][['mult', 'hosp_spend']]
    
    tspend = treatment['hosp_spend'] * treatment['mult']
    cspend = control['hosp_spend'] * control['mult']
    pval = ttest_ind(tspend, cspend, equal_var=False, alternative='less').pvalue
    diff = tspend.sum() / treatment['mult'].sum() - cspend.sum() / control['mult'].sum()
    return pd.Series({'pval': pval, 'diff': diff,
                      'tsize': len(treatment), 'csize': len(control)})
    
xdf = df[df['cohort_id'].isin(counts.index)]
sig = xdf.groupby('cohort_id').apply(compare_within_cohort)
# Out:
# /home/jaidevd/conda/lib/python3.9/site-packages/scipy/stats/_axis_nan_policy.py:531: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
sig = sig[sig['pval'] < 0.05]
sig['frac'] = abs(sig['tsize'] / sig['csize'] - 1)

# %%
sig.sort_values('diff').head()
# Out:
#                pval         diff  tsize  csize      frac
# cohort_id
# 8881       0.024730 -3079.351367    3.0    2.0  0.500000
# 12071      0.007425 -2842.144830    2.0    7.0  0.714286
# 20957      0.045737 -2706.562429    2.0    3.0  0.333333
# 1274       0.001767 -2336.576311    2.0    8.0  0.750000
# 18245      0.041550 -2201.874268    2.0   13.0  0.846154

# %%
good = cohorts[cohorts['cohort_id'].isin(sig.index)].drop_duplicates()

# %%
good
# Out:
#          sector  nss_region              max_income_from  hoh_religion  \
# hhid
# 46736202  rural          22              self-employment      Hinduism
# 46798204  rural          21                         None      Hinduism
# 46954301  rural          51  regular wage/salary earning      Hinduism
# 46499303  rural          61                casual labour      Hinduism
# 46427301  rural          62                casual labour      Hinduism
# 46896201  rural          85              self-employment      Hinduism
# 46890203  rural          85              self-employment      Hinduism
# 46000302  rural          83                casual labour      Hinduism
# 47960301  rural          92              self-employment      Hinduism
# 43528309  rural         101              self-employment      Hinduism
# 45037302  rural         161                casual labour      Hinduism
# 45117303  rural         171              self-employment  Christianity
# 45117310  rural         171              self-employment  Christianity
# 42612301  rural         231                casual labour      Hinduism
# 42516312  rural         245                casual labour      Hinduism
# 42497201  rural         243              self-employment      Hinduism
# 42497308  rural         243              self-employment      Hinduism
# 42836204  rural         274              self-employment      Hinduism
# 48798313  rural         272              self-employment      Hinduism
# 48986312  rural         282              self-employment      Hinduism
# 48292309  rural         281                casual labour      Hinduism
# 40376308  rural         321                         None         Islam
# 40373310  rural         321                         None      Hinduism
# 40143312  rural         361              self-employment      Hinduism
# 26737202  urban          22              self-employment      Hinduism
# 26516309  urban          51  regular wage/salary earning      Hinduism
# 23646302  urban         131              self-employment  Christianity
# 23454202  urban         171              self-employment  Christianity
# 29611308  urban         241  regular wage/salary earning      Hinduism
# 29766101  urban         241              self-employment      Hinduism
# 24776102  urban         281                         None      Hinduism
# 24256203  urban         321                casual labour      Hinduism
# 24253309  urban         321              self-employment      Hinduism
# 24185304  urban         331  regular wage/salary earning      Hinduism
# 24188201  urban         331  regular wage/salary earning      Hinduism
# 22557303  urban         361  regular wage/salary earning      Hinduism
#
#          family_size  has_child  has_elderly                       caste  \
# hhid
# 46736202     nuclear      False         True                      others
# 46798204     nuclear      False         True                      others
# 46954301     nuclear       True        False                      others
# 46499303       large       True         True        scheduled caste (SC)
# 46427301       large       True         True        scheduled caste (SC)
# 46896201       large       True        False  other backward class (OBC)
# 46890203     nuclear      False         True  other backward class (OBC)
# 46000302     nuclear       True        False        scheduled tribe (ST)
# 47960301       large       True         True        scheduled caste (SC)
# 43528309     nuclear       True        False        scheduled caste (SC)
# 45037302     nuclear      False        False        scheduled caste (SC)
# 45117303       large       True         True        scheduled tribe (ST)
# 45117310       large       True        False        scheduled tribe (ST)
# 42612301     nuclear       True        False        scheduled caste (SC)
# 42516312     nuclear       True        False        scheduled caste (SC)
# 42497201       large       True         True  other backward class (OBC)
# 42497308     nuclear      False         True  other backward class (OBC)
# 42836204       large       True        False                      others
# 48798313       large       True         True                      others
# 48986312     nuclear      False        False                      others
# 48292309       large       True        False  other backward class (OBC)
# 40376308     nuclear      False         True  other backward class (OBC)
# 40373310     nuclear      False         True                      others
# 40143312     nuclear       True        False        scheduled tribe (ST)
# 26737202     nuclear      False        False                      others
# 26516309     nuclear      False        False                      others
# 23646302     nuclear       True        False        scheduled tribe (ST)
# 23454202       large       True        False        scheduled tribe (ST)
# 29611308     nuclear       True         True                      others
# 29766101     nuclear      False         True                      others
# 24776102     nuclear      False         True  other backward class (OBC)
# 24256203       large       True         True  other backward class (OBC)
# 24253309     nuclear      False         True  other backward class (OBC)
# 24185304     nuclear      False        False        scheduled caste (SC)
# 24188201     nuclear       True        False        scheduled caste (SC)
# 22557303     nuclear       True        False  other backward class (OBC)
#
#           cohort_id
# hhid
# 46736202        445
# 46798204        368
# 46954301       1022
# 46499303       1158
# 46427301       1274
# 46896201       2048
# 46890203       2029
# 46000302       1765
# 47960301       2349
# 43528309       3001
# 45037302       3964
# 45117303       4223
# 45117310       4221
# 42612301       6697
# 42516312       7791
# 42497201       7684
# 42497308       7662
# 42836204       8569
# 48798313       8245
# 48986312       9102
# 48292309       8881
# 40376308      10060
# 40373310      10050
# 40143312      10984
# 26737202      11569
# 26516309      12071
# 23646302      14754
# 23454202      15293
# 29611308      18201
# 29766101      18245
# 24776102      19927
# 24256203      20908
# 24253309      20957
# 24185304      21218
# 24188201      21227
# 22557303      21913

# %%
good['max_income_from'].value_counts(normalize=True)
# Out:
# max_income_from
# self-employment                0.5625
# casual labour                  0.2500
# regular wage/salary earning    0.1875
# Name: proportion, dtype: float64

# %%
good[good['nss_region'] == 321]
# Out:
#          sector  nss_region  max_income_from hoh_religion family_size  \
# hhid
# 40376308  rural         321             None        Islam     nuclear
# 40373310  rural         321             None     Hinduism     nuclear
# 24256203  urban         321    casual labour     Hinduism       large
# 24253309  urban         321  self-employment     Hinduism     nuclear
#
#           has_child  has_elderly                       caste  cohort_id
# hhid
# 40376308      False         True  other backward class (OBC)      10060
# 40373310      False         True                      others      10050
# 24256203       True         True  other backward class (OBC)      20908
# 24253309      False         True  other backward class (OBC)      20957

# %%
def compare_within_cohort(xdf):
    treatment = xdf[xdf['is_benefit_healthscheme'] == 1][['mult', 'nohosp']]
    control = xdf[xdf['is_benefit_healthscheme'] != 1][['mult', 'nohosp']]
    
    tspend = treatment['nohosp'] * treatment['mult']
    cspend = control['nohosp'] * control['mult']
    pval = ttest_ind(tspend, cspend, equal_var=False, alternative='less').pvalue
    diff = tspend.sum() / treatment['mult'].sum() - cspend.sum() / control['mult'].sum()
    return pd.Series({'pval': pval, 'diff': diff,
                      'tsize': len(treatment), 'csize': len(control)})
    
xdf = df[df['cohort_id'].isin(counts.index)]
sig = xdf.groupby('cohort_id').apply(compare_within_cohort)
# Out:
# /home/jaidevd/conda/lib/python3.9/site-packages/scipy/stats/_axis_nan_policy.py:531: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# /home/jaidevd/conda/lib/python3.9/site-packages/scipy/stats/_axis_nan_policy.py:531: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
sig = sig[sig['pval'] < 0.05]
sig['frac'] = abs(sig['tsize'] / sig['csize'] - 1)

# %%
good = cohorts[cohorts['cohort_id'].isin(sig.index)].drop_duplicates()

# %%
good
# Out:
#          sector  nss_region              max_income_from  hoh_religion  \
# hhid
# 46626307  rural          13              self-employment         Islam
# 46319101  rural          32              self-employment       Sikhism
# 46427301  rural          62                casual labour      Hinduism
# 46896305  rural          85              self-employment      Hinduism
# 46060301  rural          81              self-employment      Hinduism
# 46000302  rural          83                casual labour      Hinduism
# 46000308  rural          83              self-employment      Hinduism
# 47953313  rural          93              self-employment      Hinduism
# 43041302  rural         102              self-employment      Hinduism
# 45336204  rural         121              self-employment  Christianity
# 45336205  rural         121              self-employment  Christianity
# 45334307  rural         121              self-employment  Christianity
# 45515302  rural         131              self-employment  Christianity
# 45037302  rural         161                casual labour      Hinduism
# 45116316  rural         171                casual labour  Christianity
# 45117302  rural         171                casual labour  Christianity
# 49475203  rural         195              self-employment      Hinduism
# 49472302  rural         195              self-employment      Hinduism
# 44577310  rural         211              self-employment      Hinduism
# 44970308  rural         212                casual labour      Hinduism
# 44970313  rural         212              self-employment      Hinduism
# 42612301  rural         231                casual labour      Hinduism
# 42612302  rural         231                casual labour      Hinduism
# 42507104  rural         245              self-employment      Hinduism
# 48966301  rural         283                casual labour      Hinduism
# 48928201  rural         282                casual labour  Christianity
# 48155203  rural         294              self-employment      Hinduism
# 40376311  rural         321              self-employment         Islam
# 40372304  rural         321                casual labour      Hinduism
# 40573305  rural         322              self-employment      Hinduism
# 40997302  rural         334                casual labour      Hinduism
# 40997305  rural         334                casual labour      Hinduism
# 40993302  rural         334  regular wage/salary earning      Hinduism
# 40413301  rural         331  regular wage/salary earning      Hinduism
# 40833301  rural         333              self-employment      Hinduism
# 40143312  rural         361              self-employment      Hinduism
# 26652202  urban          13  regular wage/salary earning         Islam
# 26658309  urban          13                casual labour         Islam
# 26650304  urban          13              self-employment         Islam
# 26516309  urban          51  regular wage/salary earning      Hinduism
# 23317303  urban         151  regular wage/salary earning  Christianity
# 23313311  urban         151  regular wage/salary earning  Christianity
# 23938318  urban         161  regular wage/salary earning      Hinduism
# 23846311  urban         194  regular wage/salary earning      Hinduism
# 29611308  urban         241  regular wage/salary earning      Hinduism
# 24776102  urban         281                         None      Hinduism
# 24096309  urban         334              self-employment      Hinduism
# 24097306  urban         334                         None      Hinduism
# 24183304  urban         331              self-employment      Hinduism
# 22557303  urban         361  regular wage/salary earning      Hinduism
#
#          family_size  has_child  has_elderly                       caste  \
# hhid
# 46626307     nuclear       True        False                      others
# 46319101       large       True         True                      others
# 46427301       large       True         True        scheduled caste (SC)
# 46896305     nuclear       True        False  other backward class (OBC)
# 46060301       large       True        False  other backward class (OBC)
# 46000302     nuclear       True        False        scheduled tribe (ST)
# 46000308       large       True        False        scheduled tribe (ST)
# 47953313     nuclear      False        False  other backward class (OBC)
# 43041302       large       True        False  other backward class (OBC)
# 45336204     nuclear       True        False        scheduled tribe (ST)
# 45336205       large       True         True        scheduled tribe (ST)
# 45334307       large       True        False        scheduled tribe (ST)
# 45515302     nuclear      False         True        scheduled tribe (ST)
# 45037302     nuclear      False        False        scheduled caste (SC)
# 45116316     nuclear       True        False        scheduled tribe (ST)
# 45117302       large       True        False        scheduled tribe (ST)
# 49475203     nuclear      False         True                      others
# 49472302     nuclear       True        False                      others
# 44577310     nuclear      False        False  other backward class (OBC)
# 44970308     nuclear       True        False        scheduled tribe (ST)
# 44970313     nuclear      False        False  other backward class (OBC)
# 42612301     nuclear       True        False        scheduled caste (SC)
# 42612302     nuclear       True        False  other backward class (OBC)
# 42507104     nuclear       True        False  other backward class (OBC)
# 48966301     nuclear       True        False        scheduled caste (SC)
# 48928201     nuclear      False        False        scheduled caste (SC)
# 48155203       large       True         True  other backward class (OBC)
# 40376311       large       True         True  other backward class (OBC)
# 40372304     nuclear       True         True  other backward class (OBC)
# 40573305     nuclear      False         True  other backward class (OBC)
# 40997302     nuclear      False         True        scheduled caste (SC)
# 40997305     nuclear      False        False        scheduled caste (SC)
# 40993302     nuclear       True        False  other backward class (OBC)
# 40413301     nuclear      False        False  other backward class (OBC)
# 40833301     nuclear      False        False  other backward class (OBC)
# 40143312     nuclear       True        False        scheduled tribe (ST)
# 26652202     nuclear       True        False                      others
# 26658309     nuclear       True        False                      others
# 26650304       large       True        False                      others
# 26516309     nuclear      False        False                      others
# 23317303     nuclear       True        False        scheduled tribe (ST)
# 23313311     nuclear      False         True        scheduled tribe (ST)
# 23938318     nuclear      False        False  other backward class (OBC)
# 23846311     nuclear      False         True                      others
# 29611308     nuclear       True         True                      others
# 24776102     nuclear      False         True  other backward class (OBC)
# 24096309     nuclear      False         True  other backward class (OBC)
# 24097306     nuclear      False         True  other backward class (OBC)
# 24183304     nuclear      False        False  other backward class (OBC)
# 22557303     nuclear       True        False  other backward class (OBC)
#
#           cohort_id
# hhid
# 46626307        268
# 46319101        863
# 46427301       1274
# 46896305       2033
# 46060301       1559
# 46000302       1765
# 46000308       1825
# 47953313       2501
# 43041302       3194
# 45336204       3550
# 45336205       3555
# 45334307       3554
# 45515302       3651
# 45037302       3964
# 45116316       4136
# 45117302       4142
# 49475203       5625
# 49472302       5630
# 44577310       6120
# 44970308       6205
# 44970313       6266
# 42612301       6697
# 42612302       6695
# 42507104       7848
# 48966301       9172
# 48928201       9000
# 48155203       9742
# 40376311      10037
# 40372304       9929
# 40573305      10174
# 40997302      10609
# 40997305      10604
# 40993302      10644
# 40413301      10275
# 40833301      10553
# 40143312      10984
# 26652202      11408
# 26658309      11393
# 26650304      11435
# 26516309      12071
# 23317303      15065
# 23313311      15064
# 23938318      15142
# 23846311      16151
# 29611308      18201
# 24776102      19927
# 24096309      21651
# 24097306      21684
# 24183304      21272
# 22557303      21913

# %%
_ = sig.sort_values('diff')
cohorts[cohorts['cohort_id'] == 10174]
# Out:
#          sector  nss_region  max_income_from hoh_religion family_size  \
# hhid
# 40573305  rural         322  self-employment     Hinduism     nuclear
# 40573310  rural         322  self-employment     Hinduism     nuclear
# 40574302  rural         322  self-employment     Hinduism     nuclear
# 40572201  rural         322  self-employment     Hinduism     nuclear
# 40570307  rural         322  self-employment     Hinduism     nuclear
# ...         ...         ...              ...          ...         ...
# 40935305  rural         322  self-employment     Hinduism     nuclear
# 40939203  rural         322  self-employment     Hinduism     nuclear
# 40938203  rural         322  self-employment     Hinduism     nuclear
# 40938204  rural         322  self-employment     Hinduism     nuclear
# 40930313  rural         322  self-employment     Hinduism     nuclear
#
#           has_child  has_elderly                       caste  cohort_id
# hhid
# 40573305      False         True  other backward class (OBC)      10174
# 40573310      False         True  other backward class (OBC)      10174
# 40574302      False         True  other backward class (OBC)      10174
# 40572201      False         True  other backward class (OBC)      10174
# 40570307      False         True  other backward class (OBC)      10174
# ...             ...          ...                         ...        ...
# 40935305      False         True  other backward class (OBC)      10174
# 40939203      False         True  other backward class (OBC)      10174
# 40938203      False         True  other backward class (OBC)      10174
# 40938204      False         True  other backward class (OBC)      10174
# 40930313      False         True  other backward class (OBC)      10174
#
# [75 rows x 9 columns]
