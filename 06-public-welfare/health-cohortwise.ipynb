# %%
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind

# %%
df = pd.read_parquet('data/health-indicators.parquet')
cohorts = pd.read_parquet('data/hh-cohorts.parquet')
hh = pd.read_parquet('data/hh_details.parquet')
cons = pd.read_parquet('data/baskets-consumption-value.parquet')

# %%
df = df[df['is_hospitalization'] != 4]
df['mult'] = hh['multiplier']
df['cohort_id'] = cohorts['cohort_id']

# %%
df['hosp_spend'] = cons.loc[df.index, "HOSP"]

# %%
df.head()
# Out:
#           is_hhmem_pmjay  is_hospitalization  is_benefit_healthscheme   mult  \
# hhid
# 22300304               2                   2                      2.0  28599
# 22300308               2                   2                      2.0  28599
# 22300313               2                   2                      2.0  28599
# 22301201               2                   3                      2.0  20463
# 22301310               2                   1                      2.0  16099
#
#           cohort_id   hosp_spend
# hhid
# 22300304      21773  3250.000000
# 22300308      21722  2650.000000
# 22300313      21728  3916.666667
# 22301201      21732   500.000000
# 22301310      21782     4.166667

# %%
counts = df.groupby('cohort_id')['is_benefit_healthscheme'].value_counts().unstack().dropna()
counts = counts[counts.min(axis=1) > 1]

# %%
def compare_within_cohort(xdf):
    treatment = xdf[xdf['is_benefit_healthscheme'] == 1][['mult', 'hosp_spend']]
    control = xdf[xdf['is_benefit_healthscheme'] != 1][['mult', 'hosp_spend']]
    
    tspend = treatment['hosp_spend'] * treatment['mult']
    cspend = control['hosp_spend'] * control['mult']
    pval = ttest_ind(tspend, cspend, equal_var=False, alternative='less').pvalue
    diff = tspend.sum() / treatment['mult'].sum() - cspend.sum() / control['mult'].sum()
    return pd.Series({'pval': pval, 'diff': diff,
                      'tsize': len(treatment), 'csize': len(control)})
    
xdf = df[df['cohort_id'].isin(counts.index)]
sig = xdf.groupby('cohort_id').apply(compare_within_cohort)
# Out:
# /Users/jaidevd/conda/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:586: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# /var/folders/nz/p2j_7wnx56q0b61h97fxmmv40000gn/T/ipykernel_15242/2851148121.py:13: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sig = xdf.groupby('cohort_id').apply(compare_within_cohort)

# %%
sig = pd.concat([sig, cohorts.drop_duplicates().set_index('cohort_id', verify_integrity=True).loc[sig.index]], axis=1, verify_integrity=True)

# %%
sig.to_csv("/tmp/sig.csv", index=True)

# %%
sig.head()
# Out:
#                pval        diff  tsize  csize sector  nss_region  \
# cohort_id
# 21         0.253369 -551.545699    2.0    2.0  rural          11
# 96         0.339139  -13.080173    3.0    2.0  rural          12
# 106        0.667360  378.132775    3.0    3.0  rural          12
# 263        0.995152  921.667480    8.0    6.0  rural          13
# 268        0.610804  551.703394    4.0    5.0  rural          13
#
#                        max_income_from hoh_religion family_size  has_child  \
# cohort_id
# 21         regular wage/salary earning     Hinduism     nuclear       True
# 96                       casual labour        Islam     nuclear       True
# 106                      casual labour        Islam       large       True
# 263                    self-employment        Islam     nuclear      False
# 268                    self-employment        Islam     nuclear       True
#
#            has_elderly                 caste
# cohort_id
# 21               False  scheduled caste (SC)
# 96               False  scheduled tribe (ST)
# 106               True  scheduled tribe (ST)
# 263              False                others
# 268              False                others

# %%
sig.to_parquet('data/summaries/01.parquet')

# %%
df['nohosp_spend'] = cons.loc[df.index, "NOHOSP"]

# %%
def compare_within_cohort(xdf):
    treatment = xdf[xdf['is_benefit_healthscheme'] == 1][['mult', 'nohosp_spend']]
    control = xdf[xdf['is_benefit_healthscheme'] != 1][['mult', 'nohosp_spend']]
    
    tspend = treatment['nohosp_spend'] * treatment['mult']
    cspend = control['nohosp_spend'] * control['mult']
    pval = ttest_ind(tspend, cspend, equal_var=False, alternative='less').pvalue
    diff = tspend.sum() / treatment['mult'].sum() - cspend.sum() / control['mult'].sum()
    return pd.Series({'pval': pval, 'diff': diff,
                      'tsize': len(treatment), 'csize': len(control)})
    
xdf = df[df['cohort_id'].isin(counts.index)]
sig = xdf.groupby('cohort_id').apply(compare_within_cohort)
# Out:
# /Users/jaidevd/conda/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:586: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# /Users/jaidevd/conda/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:586: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# /var/folders/nz/p2j_7wnx56q0b61h97fxmmv40000gn/T/ipykernel_15242/1013230934.py:13: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sig = xdf.groupby('cohort_id').apply(compare_within_cohort)

# %%
sig = pd.concat([sig, cohorts.drop_duplicates().set_index('cohort_id', verify_integrity=True).loc[sig.index]], axis=1, verify_integrity=True)

# %%
sig[sig['pval'] < 0.05].sort_values('diff')
# Out:
#                    pval        diff  tsize  csize sector  nss_region  \
# cohort_id
# 19927      3.754477e-02 -312.487329    2.0    8.0  urban         281
# 10037      3.471111e-05 -300.857498    4.0   14.0  rural         321
# 863        9.783334e-03 -283.791214    2.0   16.0  rural          32
# 10174      1.626952e-02 -220.884439   10.0   15.0  rural         322
# 12071      1.630427e-02 -208.922818    2.0    7.0  urban          51
# cohort_id
# 19927                             None      Hinduism     nuclear      False
# 10037                  self-employment         Islam       large       True
# 863                    self-employment       Sikhism       large       True
# 10174                  self-employment      Hinduism     nuclear      False
# 12071      regular wage/salary earning      Hinduism     nuclear      False
# 6120                   self-employment      Hinduism     nuclear      False
# 16151      regular wage/salary earning      Hinduism     nuclear      False
# 21684                             None      Hinduism     nuclear      False
# 2033                   self-employment      Hinduism     nuclear       True
# 6266                   self-employment      Hinduism     nuclear      False
# 5630                   self-employment      Hinduism     nuclear       True
# 1559                   self-employment      Hinduism       large       True
# 15142      regular wage/salary earning      Hinduism     nuclear      False
# 9742                   self-employment      Hinduism       large       True
# 10644      regular wage/salary earning      Hinduism     nuclear       True
# 5625                   self-employment      Hinduism     nuclear      False
# 10553                  self-employment      Hinduism     nuclear      False
# 1274                     casual labour      Hinduism       large       True
# 10984                  self-employment      Hinduism     nuclear       True
# 21651                  self-employment      Hinduism     nuclear      False
# 9929                     casual labour      Hinduism     nuclear       True
# 21272                  self-employment      Hinduism     nuclear      False
# 9000                     casual labour  Christianity     nuclear      False
# 15065      regular wage/salary earning  Christianity     nuclear       True
# 10275      regular wage/salary earning      Hinduism     nuclear      False
# 2501                   self-employment      Hinduism     nuclear      False
# 11435                  self-employment         Islam       large       True
# 1825                   self-employment      Hinduism       large       True
# 11393                    casual labour         Islam     nuclear       True
# 268                    self-employment         Islam     nuclear       True
# 3964                     casual labour      Hinduism     nuclear      False
# 10604                    casual labour      Hinduism     nuclear      False
# 11408      regular wage/salary earning         Islam     nuclear       True
# 1765                     casual labour      Hinduism     nuclear       True
# 15064      regular wage/salary earning  Christianity     nuclear      False
# 3651                   self-employment  Christianity     nuclear      False
# 18201      regular wage/salary earning      Hinduism     nuclear       True
# 3554                   self-employment  Christianity       large       True
# 10609                    casual labour      Hinduism     nuclear      False
# 6697                     casual labour      Hinduism     nuclear       True
# 3194                   self-employment      Hinduism       large       True
# 3555                   self-employment  Christianity       large       True
# 3550                   self-employment  Christianity     nuclear       True
# 4142                     casual labour  Christianity       large       True
# 9172                     casual labour      Hinduism     nuclear       True
# 21913      regular wage/salary earning      Hinduism     nuclear       True
# 7848                   self-employment      Hinduism     nuclear       True
# 6695                     casual labour      Hinduism     nuclear       True
# 6205                     casual labour      Hinduism     nuclear       True
# 4136                     casual labour  Christianity     nuclear       True
#
#            has_elderly                       caste
# cohort_id
# 19927             True  other backward class (OBC)
# 10037             True  other backward class (OBC)
# 863               True                      others
# 10174             True  other backward class (OBC)
# 12071            False                      others
# 6120             False  other backward class (OBC)
# 16151             True                      others
# 21684             True  other backward class (OBC)
# 2033             False  other backward class (OBC)
# 6266             False  other backward class (OBC)
# 5630             False                      others
# 1559             False  other backward class (OBC)
# 15142            False  other backward class (OBC)
# 9742              True  other backward class (OBC)
# 10644            False  other backward class (OBC)
# 5625              True                      others
# 10553            False  other backward class (OBC)
# 1274              True        scheduled caste (SC)
# 10984            False        scheduled tribe (ST)
# 21651             True  other backward class (OBC)
# 9929              True  other backward class (OBC)
# 21272            False  other backward class (OBC)
# 9000             False        scheduled caste (SC)
# 15065            False        scheduled tribe (ST)
# 10275            False  other backward class (OBC)
# 2501             False  other backward class (OBC)
# 11435            False                      others
# 1825             False        scheduled tribe (ST)
# 11393            False                      others
# 268              False                      others
# 3964             False        scheduled caste (SC)
# 10604            False        scheduled caste (SC)
# 11408            False                      others
# 1765             False        scheduled tribe (ST)
# 15064             True        scheduled tribe (ST)
# 3651              True        scheduled tribe (ST)
# 18201             True                      others
# 3554             False        scheduled tribe (ST)
# 10609             True        scheduled caste (SC)
# 6697             False        scheduled caste (SC)
# 3194             False  other backward class (OBC)
# 3555              True        scheduled tribe (ST)
# 3550             False        scheduled tribe (ST)
# 4142             False        scheduled tribe (ST)
# 9172             False        scheduled caste (SC)
# 21913            False  other backward class (OBC)
# 7848             False  other backward class (OBC)
# 6695             False  other backward class (OBC)
# 6205             False        scheduled tribe (ST)
# 4136             False        scheduled tribe (ST)

# %%
sig.to_parquet('data/summaries/02.parquet')

# %%
# Food?

# %%
df['FOOD'] = cons.loc[df.index, "FOOD"]

# %%
def compare_within_cohort(xdf):
    treatment = xdf[xdf['is_benefit_healthscheme'] == 1][['mult', 'FOOD']]
    control = xdf[xdf['is_benefit_healthscheme'] != 1][['mult', 'FOOD']]
    
    tspend = treatment['FOOD'] * treatment['mult']
    cspend = control['FOOD'] * control['mult']
    pval = ttest_ind(tspend, cspend, equal_var=False, alternative='greater').pvalue
    diff = tspend.sum() / treatment['mult'].sum() - cspend.sum() / control['mult'].sum()
    return pd.Series({'pval': pval, 'diff': diff,
                      'tsize': len(treatment), 'csize': len(control)})
    
xdf = df[df['cohort_id'].isin(counts.index)]
sig = xdf.groupby('cohort_id').apply(compare_within_cohort)
# Out:
# /var/folders/nz/p2j_7wnx56q0b61h97fxmmv40000gn/T/ipykernel_15242/3419655699.py:13: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sig = xdf.groupby('cohort_id').apply(compare_within_cohort)

# %%
sig = pd.concat([sig, cohorts.drop_duplicates().set_index('cohort_id', verify_integrity=True).loc[sig.index]], axis=1, verify_integrity=True)

# %%
sig[sig['pval'] < 0.05].sort_values('diff', ascending=False)
# Out:
#                pval         diff  tsize  csize sector  nss_region  \
# cohort_id
# 14787      0.000106  8566.085065    2.0    4.0  urban         131
# 21038      0.023101  8121.541671    2.0    5.0  urban         322
# 430        0.021685  7991.825518    5.0    7.0  rural          22
# 9110       0.006597  6321.793244    2.0    5.0  rural         282
# 5569       0.005915  6184.571020    3.0    3.0  rural         195
# 6588       0.010835  6073.204946    2.0    3.0  rural         222
# 1682       0.002278  5732.902717   10.0    6.0  rural          82
# 4013       0.043734  5622.483240    2.0   12.0  rural         161
# 8950       0.005427  4983.498018    3.0   13.0  rural         281
# 7786       0.035463  4442.010660    2.0    2.0  rural         245
# 1651       0.020994  4380.628697    3.0    2.0  rural          82
# 465        0.017861  3880.431483    2.0    4.0  rural          22
# 17114      0.001261  3802.646000    4.0    2.0  urban         222
# 7791       0.021347  3637.706692    2.0    4.0  rural         245
# 1616       0.015387  3576.970570    3.0    2.0  rural          82
# 11425      0.001124  3505.675248    4.0    9.0  urban          13
# 15186      0.016085  3405.837050    2.0    7.0  urban         161
# 3785       0.010391  3016.711905    3.0    2.0  rural         141
# 3551       0.042340  2827.483229    5.0    5.0  rural         121
# 342        0.015889  2379.836588    2.0    4.0  rural          21
# 8913       0.014602  2357.031941    2.0    2.0  rural         281
# 6332       0.036097  2194.405484    3.0    8.0  rural         213
# 20090      0.023971  2180.145121    2.0   10.0  urban         283
# 10247      0.012895  1709.460980    6.0   22.0  rural         331
# 13074      0.024080  1707.581871    4.0    3.0  urban          84
# 5222       0.025748  1564.891610    2.0    4.0  rural         192
# 1817       0.036036  1557.434754    3.0    2.0  rural          83
# 21008      0.040140  1494.225961    2.0    3.0  urban         322
# 9109       0.029439  1301.307169    4.0    2.0  rural         282
# 3972       0.025661  1175.043703    3.0   23.0  rural         161
# 6984       0.008723   826.540593    2.0    4.0  rural         233
# 17853      0.005136   434.444843    2.0    6.0  urban         234
# 8623       0.010464   184.009201    2.0   11.0  rural         275
# 21142      0.000040 -1722.805877    2.0   13.0  urban         322
#
#                        max_income_from  hoh_religion family_size  has_child  \
# cohort_id
# 14787                             None  Christianity     nuclear      False
# 21038                    casual labour      Hinduism       large       True
# 430        regular wage/salary earning      Hinduism       large       True
# 9110                   self-employment      Hinduism     nuclear       True
# 5569                     casual labour      Hinduism       large       True
# 6588                   self-employment      Hinduism     nuclear      False
# 1682                   self-employment      Hinduism     nuclear      False
# 4013       regular wage/salary earning      Hinduism     nuclear      False
# 8950                   self-employment      Hinduism     nuclear      False
# 7786                     casual labour      Hinduism     nuclear      False
# 1651       regular wage/salary earning      Hinduism     nuclear       True
# 465                    self-employment      Hinduism       large       True
# 17114      regular wage/salary earning      Hinduism     nuclear      False
# 7791                     casual labour      Hinduism     nuclear       True
# 1616                     casual labour      Hinduism     nuclear       True
# 11425                  self-employment         Islam     nuclear      False
# 15186                  self-employment      Hinduism     nuclear       True
# 3785                   self-employment      Hinduism     nuclear       True
# 3551                   self-employment  Christianity     nuclear       True
# 342                    self-employment      Hinduism     nuclear      False
# 8913       regular wage/salary earning      Hinduism     nuclear       True
# 6332                     casual labour      Hinduism     nuclear       True
# 20090                    casual labour      Hinduism     nuclear       True
# 10247                    casual labour      Hinduism     nuclear       True
# 13074      regular wage/salary earning      Hinduism     nuclear       True
# 5222                   self-employment         Islam     nuclear       True
# 1817                   self-employment      Hinduism     nuclear       True
# 21008                    casual labour  Christianity     nuclear      False
# 9109                   self-employment      Hinduism     nuclear       True
# 3972                     casual labour      Hinduism     nuclear       True
# 6984                   self-employment      Hinduism     nuclear       True
# 17853                  self-employment      Hinduism     nuclear       True
# 8623                     casual labour      Hinduism     nuclear      False
# 21142                             None  Christianity     nuclear      False
#
#            has_elderly                       caste
# cohort_id
# 14787             True        scheduled tribe (ST)
# 21038             True  other backward class (OBC)
# 430               True                      others
# 9110             False                      others
# 5569              True        scheduled caste (SC)
# 6588             False        scheduled tribe (ST)
# 1682              True  other backward class (OBC)
# 4013             False  other backward class (OBC)
# 8950              True  other backward class (OBC)
# 7786              True  other backward class (OBC)
# 1651             False        scheduled caste (SC)
# 465               True        scheduled caste (SC)
# 17114            False  other backward class (OBC)
# 7791             False        scheduled caste (SC)
# 1616              True        scheduled caste (SC)
# 11425            False                      others
# 15186             True  other backward class (OBC)
# 3785              True                      others
# 3551              True        scheduled tribe (ST)
# 342               True  other backward class (OBC)
# 8913             False  other backward class (OBC)
# 6332             False  other backward class (OBC)
# 20090            False  other backward class (OBC)
# 10247            False        scheduled caste (SC)
# 13074            False  other backward class (OBC)
# 5222              True                      others
# 1817              True        scheduled tribe (ST)
# 21008             True  other backward class (OBC)
# 9109             False  other backward class (OBC)
# 3972             False        scheduled caste (SC)
# 6984             False                      others
# 17853            False  other backward class (OBC)
# 8623              True  other backward class (OBC)
# 21142             True                      others

# %%
# EDUCATION?
df['EDUCATION'] = cons.loc[df.index, "EDUCATION"]

def compare_within_cohort(xdf):
    treatment = xdf[xdf['is_benefit_healthscheme'] == 1][['mult', 'EDUCATION']]
    control = xdf[xdf['is_benefit_healthscheme'] != 1][['mult', 'EDUCATION']]
    
    tspend = treatment['EDUCATION'] * treatment['mult']
    cspend = control['EDUCATION'] * control['mult']
    pval = ttest_ind(tspend, cspend, equal_var=False, alternative='greater').pvalue
    diff = tspend.sum() / treatment['mult'].sum() - cspend.sum() / control['mult'].sum()
    return pd.Series({'pval': pval, 'diff': diff,
                      'tsize': len(treatment), 'csize': len(control)})
    
xdf = df[df['cohort_id'].isin(counts.index)]
sig = xdf.groupby('cohort_id').apply(compare_within_cohort)
# Out:
# /var/folders/nz/p2j_7wnx56q0b61h97fxmmv40000gn/T/ipykernel_15242/1875994270.py:16: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sig = xdf.groupby('cohort_id').apply(compare_within_cohort)

# %%
sig = pd.concat([sig, cohorts.drop_duplicates().set_index('cohort_id', verify_integrity=True).loc[sig.index]], axis=1, verify_integrity=True)

# %%
sig[sig['pval'] < 0.05].sort_values('diff', ascending=False)
# Out:
#                pval         diff  tsize  csize sector  nss_region  \
# cohort_id
# 1083       0.000686  2291.870902    2.0    6.0  rural          51
# 14937      0.040598  1805.632056    2.0   21.0  urban         141
# 1545       0.037413  1715.214939    7.0    8.0  rural          81
# 20129      0.016411  1715.005537    3.0    2.0  urban         283
# 6145       0.040498  1218.568001    5.0    3.0  rural         211
# 14955      0.037189  1121.330104    3.0   10.0  urban         141
# 17175      0.049543   697.553907    4.0    3.0  urban         222
# 20920      0.045313   564.617184    3.0    9.0  urban         321
# 11388      0.003600   460.701285    2.0    2.0  urban          13
# 4176       0.049519   325.271346    4.0    2.0  rural         171
# 17114      0.015396    28.125000    4.0    2.0  urban         222
#
#                        max_income_from hoh_religion family_size  has_child  \
# cohort_id
# 1083                   self-employment     Hinduism       large       True
# 14937                  self-employment     Hinduism     nuclear       True
# 1545                   self-employment     Hinduism     nuclear       True
# 20129      regular wage/salary earning     Hinduism     nuclear       True
# 6145                   self-employment     Hinduism       large       True
# 14955                  self-employment     Hinduism       large       True
# 17175                  self-employment     Hinduism     nuclear       True
# 20920                    casual labour        Islam       large       True
# 11388                    casual labour        Islam     nuclear      False
# 4176                     casual labour       Others       large       True
# 17114      regular wage/salary earning     Hinduism     nuclear      False
#
#            has_elderly                       caste
# cohort_id
# 1083              True  other backward class (OBC)
# 14937            False  other backward class (OBC)
# 1545             False  other backward class (OBC)
# 20129            False        scheduled caste (SC)
# 6145              True  other backward class (OBC)
# 14955             True  other backward class (OBC)
# 17175            False  other backward class (OBC)
# 20920             True  other backward class (OBC)
# 11388            False                      others
# 4176             False        scheduled tribe (ST)
# 17114            False  other backward class (OBC)

# %%
# Utilities
df['UTILITIES'] = cons.loc[df.index, "UTILITIES"]

def compare_within_cohort(xdf):
    treatment = xdf[xdf['is_benefit_healthscheme'] == 1][['mult', 'UTILITIES']]
    control = xdf[xdf['is_benefit_healthscheme'] != 1][['mult', 'UTILITIES']]
    
    tspend = treatment['UTILITIES'] * treatment['mult']
    cspend = control['UTILITIES'] * control['mult']
    pval = ttest_ind(tspend, cspend, equal_var=False, alternative='greater').pvalue
    diff = tspend.sum() / treatment['mult'].sum() - cspend.sum() / control['mult'].sum()
    return pd.Series({'pval': pval, 'diff': diff,
                      'tsize': len(treatment), 'csize': len(control)})
    
xdf = df[df['cohort_id'].isin(counts.index)]
sig = xdf.groupby('cohort_id').apply(compare_within_cohort)
sig = pd.concat([sig, cohorts.drop_duplicates().set_index('cohort_id', verify_integrity=True).loc[sig.index]], axis=1, verify_integrity=True)
sig[sig['pval'] < 0.05].sort_values('diff', ascending=False)
# Out:
# /Users/jaidevd/conda/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:586: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# /var/folders/nz/p2j_7wnx56q0b61h97fxmmv40000gn/T/ipykernel_15242/2181590619.py:16: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sig = xdf.groupby('cohort_id').apply(compare_within_cohort)
# 1703                   self-employment      Hinduism       large       True
# 1702                   self-employment      Hinduism       large       True
# 10379                    casual labour      Hinduism     nuclear       True
# 15065      regular wage/salary earning  Christianity     nuclear       True
# 20169                  self-employment      Hinduism     nuclear       True
# 1548                   self-employment      Hinduism     nuclear       True
# 1143                     casual labour      Hinduism     nuclear       True
# 20149      regular wage/salary earning         Islam     nuclear       True
# 17114      regular wage/salary earning      Hinduism     nuclear      False
#
#            has_elderly                       caste
# cohort_id
# 1616              True        scheduled caste (SC)
# 14725            False        scheduled tribe (ST)
# 4176             False        scheduled tribe (ST)
# 399              False        scheduled caste (SC)
# 6115              True                      others
# 6773             False        scheduled tribe (ST)
# 8623              True  other backward class (OBC)
# 3797              True                      others
# 1682              True  other backward class (OBC)
# 6588             False        scheduled tribe (ST)
# 3551              True        scheduled tribe (ST)
# 6146              True                      others
# 6695             False  other backward class (OBC)
# 3550             False        scheduled tribe (ST)
# 7786              True  other backward class (OBC)
# 5629             False  other backward class (OBC)
# 9612              True  other backward class (OBC)
# 14727            False        scheduled tribe (ST)
# 9109             False  other backward class (OBC)
# 7501             False        scheduled tribe (ST)
# 10904            False        scheduled caste (SC)
# 21154             True  other backward class (OBC)
# 1703             False        scheduled caste (SC)
# 1702             False                      others
# 10379            False  other backward class (OBC)
# 15065            False        scheduled tribe (ST)
# 20169            False  other backward class (OBC)
# 1548             False        scheduled tribe (ST)
# 1143             False  other backward class (OBC)
# 20149            False                      others
# 17114            False  other backward class (OBC)

# %%
# Assets
df['ASSETS'] = cons.loc[df.index, "ASSETS"]

def compare_within_cohort(xdf):
    treatment = xdf[xdf['is_benefit_healthscheme'] == 1][['mult', 'ASSETS']]
    control = xdf[xdf['is_benefit_healthscheme'] != 1][['mult', 'ASSETS']]
    
    tspend = treatment['ASSETS'] * treatment['mult']
    cspend = control['ASSETS'] * control['mult']
    pval = ttest_ind(tspend, cspend, equal_var=False, alternative='greater').pvalue
    diff = tspend.sum() / treatment['mult'].sum() - cspend.sum() / control['mult'].sum()
    return pd.Series({'pval': pval, 'diff': diff,
                      'tsize': len(treatment), 'csize': len(control)})
    
xdf = df[df['cohort_id'].isin(counts.index)]
sig = xdf.groupby('cohort_id').apply(compare_within_cohort)
sig = pd.concat([sig, cohorts.drop_duplicates().set_index('cohort_id', verify_integrity=True).loc[sig.index]], axis=1, verify_integrity=True)
sig[sig['pval'] < 0.05].sort_values('diff', ascending=False)
# Out:
# /var/folders/nz/p2j_7wnx56q0b61h97fxmmv40000gn/T/ipykernel_15242/71066061.py:16: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sig = xdf.groupby('cohort_id').apply(compare_within_cohort)
#                    pval         diff  tsize  csize sector  nss_region  \
# cohort_id
# 2003       2.822659e-02  2162.662533    3.0    3.0  rural          85
# 5187       3.992509e-02  2126.787518    2.0    2.0  rural         192
# 3673       4.497647e-02  1743.696887    2.0    2.0  rural         131
# 21142      1.733402e-09  1727.108397    2.0   13.0  urban         322
# 10604      3.005045e-02  1504.791235    3.0   17.0  rural         334
# 9109       7.768504e-03  1406.490369    4.0    2.0  rural         282
# 2501       1.983233e-02  1359.321595    2.0   24.0  rural          93
# 14754      2.622262e-02  1273.660577    2.0    6.0  urban         131
# 14787      1.778750e-02  1028.004259    2.0    4.0  urban         131
# 9103       1.968053e-02   858.114253    4.0    2.0  rural         282
# 1490       3.295336e-02   817.038394    4.0    2.0  rural          81
# 8881       3.973844e-02   772.220683    3.0    2.0  rural         281
# 3862       4.607221e-02   468.460552    4.0    6.0  rural         142
# 7097       1.418965e-02   464.714922    2.0    6.0  rural         234
# 1612       1.549524e-02   424.458693   14.0   17.0  rural          82
# 10494      2.483271e-02   401.823629    2.0   10.0  rural         333
# 5569       9.621886e-03   329.514338    3.0    3.0  rural         195
# 6885       2.911129e-02   328.670620    2.0    3.0  rural         232
# 4176       4.248155e-02   317.946402    4.0    2.0  rural         171
# 6922       1.844852e-02   313.573034    4.0    4.0  rural         233
# 21956      1.385437e-02   284.685884    2.0   21.0  urban         361
# 9020       4.410504e-02   112.523462    3.0    7.0  rural         282
#
#                        max_income_from  hoh_religion family_size  has_child  \
# cohort_id
# 2003       regular wage/salary earning      Hinduism       large       True
# 5187                   self-employment      Hinduism     nuclear      False
# 3673                              None  Christianity     nuclear      False
# 21142                             None  Christianity     nuclear      False
# 10604                    casual labour      Hinduism     nuclear      False
# 9109                   self-employment      Hinduism     nuclear       True
# 2501                   self-employment      Hinduism     nuclear      False
# 14754                  self-employment  Christianity     nuclear       True
# 14787                             None  Christianity     nuclear      False
# 9103                   self-employment      Hinduism     nuclear      False
# 1490                     casual labour      Hinduism       large       True
# 8881                     casual labour      Hinduism       large       True
# 3862                   self-employment  Christianity       large      False
# 7097                   self-employment      Hinduism     nuclear      False
# 1612                     casual labour      Hinduism     nuclear       True
# 10494                    casual labour      Hinduism     nuclear       True
# 5569                     casual labour      Hinduism       large       True
# 6885                   self-employment      Hinduism       large       True
# 4176                     casual labour        Others       large       True
# 6922                     casual labour      Hinduism     nuclear       True
# 21956                  self-employment      Hinduism     nuclear      False
# 9020                     casual labour      Hinduism     nuclear       True
#
#            has_elderly                       caste
# cohort_id
# 2003             False  other backward class (OBC)
# 5187              True  other backward class (OBC)
# 3673              True        scheduled tribe (ST)
# 21142             True                      others
# 10604            False        scheduled caste (SC)
# 9109             False  other backward class (OBC)
# 2501             False  other backward class (OBC)
# 14754            False        scheduled tribe (ST)
# 14787             True        scheduled tribe (ST)
# 9103             False        scheduled caste (SC)
# 1490             False  other backward class (OBC)
# 8881             False  other backward class (OBC)
# 3862              True        scheduled tribe (ST)
# 7097             False  other backward class (OBC)
# 1612             False        scheduled caste (SC)
# 10494            False        scheduled caste (SC)
# 5569              True        scheduled caste (SC)
# 6885              True  other backward class (OBC)
# 4176             False        scheduled tribe (ST)
# 6922             False        scheduled caste (SC)
# 21956            False  other backward class (OBC)
# 9020             False  other backward class (OBC)
